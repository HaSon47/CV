# %%
import yaml
from runners.ViTRunner import ViTRunner
from utils.utils import dict_to_namespace
from data.OxfordIIIPetDataset import OxfordIIIPetDataset

# %%
config_path = './config/config.yml'
with open(config_path, 'r') as file:
    config = yaml.safe_load(file)
config = dict_to_namespace(config)

run = ViTRunner(config)
dataset = OxfordIIIPetDataset(config.dataset.oxfordiiipet_folder_path, config.dataset.model_path, pretrained=config.runner_model.use_pretrained)
run.init_data(dataset)
run.train()
run.test()
# Out:
# ViT from scrach
# Epoch1/2: 100%|██████████| 368/368 [00:24<00:00, 14.80it/s, accuracy=2.51, loss=3.61]
# Train Loss: 3.6728, Train Accuracy: 2.51%
# Validation Loss: 3.6214, Validation Accuracy: 3.53%
# Epoch2/2: 100%|██████████| 368/368 [00:23<00:00, 15.43it/s, accuracy=2.31, loss=3.62]
# Train Loss: 3.6245, Train Accuracy: 2.31%
# Validation Loss: 3.6220, Validation Accuracy: 2.17%
# Validation Loss: 3.6269, Validation Accuracy: 1.90%
# (3.626870492230291, 1.9021739130434783)

# %%
run.plot_history()

# %%
config_path = './config/config.yml'
with open(config_path, 'r') as file:
    config = yaml.safe_load(file)
config = dict_to_namespace(config)

run = ViTRunner(config)
dataset = OxfordIIIPetDataset(config.dataset.oxfordiiipet_folder_path, config.dataset.model_path, pretrained=config.runner_model.use_pretrained)
run.init_data(dataset)
run.train()
run.test()
# Out:
# pretrained_ViT
# Epoch1/2:  10%|█         | 37/368 [02:34<23:01,  4.17s/it, accuracy=4.39, loss=3.61]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       7 dataset = OxfordIIIPetDataset(config.dataset.oxfordiiipet_folder_path, config.dataset.model_path, pretrained=config.runner_model.use_pretrained)
#       8 run.init_data(dataset)
# ----> 9 run.train()
#      10 run.test()
#
# File c:\Users\Lenovo\OneDrive - Hanoi University of Science and Technology\Desktop\DL\CV\ViT_ver2\runners\ViTRunner.py:60, in ViTRunner.train(self)
#      57 images, labels = batch['pixel_values'].to(self.device), batch['labels'].to(self.device)
#      59 #Forward
# ---> 60 outputs = self.model(images)
#      61 if self.use_pretrained:
#      62     outputs = outputs.logits #####
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\vit\modeling_vit.py:856, in ViTForImageClassification.forward(self, pixel_values, head_mask, labels, output_attentions, output_hidden_states, interpolate_pos_encoding, return_dict)
#     848 r"""
#     849 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     850     Labels for computing the image classification/regression loss. Indices should be in `[0, ...,
#     851     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     852     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     853 """
#     854 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 856 outputs = self.vit(
#     857     pixel_values,
#     858     head_mask=head_mask,
#     859     output_attentions=output_attentions,
#     860     output_hidden_states=output_hidden_states,
#     861     interpolate_pos_encoding=interpolate_pos_encoding,
#     862     return_dict=return_dict,
#     863 )
#     865 sequence_output = outputs[0]
#     867 logits = self.classifier(sequence_output[:, 0, :])
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\vit\modeling_vit.py:639, in ViTModel.forward(self, pixel_values, bool_masked_pos, head_mask, output_attentions, output_hidden_states, interpolate_pos_encoding, return_dict)
#     633     pixel_values = pixel_values.to(expected_dtype)
#     635 embedding_output = self.embeddings(
#     636     pixel_values, bool_masked_pos=bool_masked_pos, interpolate_pos_encoding=interpolate_pos_encoding
#     637 )
# --> 639 encoder_outputs = self.encoder(
#     640     embedding_output,
#     641     head_mask=head_mask,
#     642     output_attentions=output_attentions,
#     643     output_hidden_states=output_hidden_states,
#     644     return_dict=return_dict,
#     645 )
#     646 sequence_output = encoder_outputs[0]
#     647 sequence_output = self.layernorm(sequence_output)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\vit\modeling_vit.py:468, in ViTEncoder.forward(self, hidden_states, head_mask, output_attentions, output_hidden_states, return_dict)
#     461     layer_outputs = self._gradient_checkpointing_func(
#     462         layer_module.__call__,
#     463         hidden_states,
#     464         layer_head_mask,
#     465         output_attentions,
#     466     )
#     467 else:
# --> 468     layer_outputs = layer_module(hidden_states, layer_head_mask, output_attentions)
#     470 hidden_states = layer_outputs[0]
#     472 if output_attentions:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\vit\modeling_vit.py:426, in ViTLayer.forward(self, hidden_states, head_mask, output_attentions)
#     424 # in ViT, layernorm is also applied after self-attention
#     425 layer_output = self.layernorm_after(hidden_states)
# --> 426 layer_output = self.intermediate(layer_output)
#     428 # second residual connection is done here
#     429 layer_output = self.output(layer_output, hidden_states)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\vit\modeling_vit.py:367, in ViTIntermediate.forward(self, hidden_states)
#     366 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 367     hidden_states = self.dense(hidden_states)
#     368     hidden_states = self.intermediate_act_fn(hidden_states)
#     370     return hidden_states
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
